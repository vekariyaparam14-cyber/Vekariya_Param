# %% [markdown]
# # <---------------- Session-4 -------------------->

# %% [markdown]
# ### Task.1 :-

# %%
playlist_ids = [664148451,511515115,58519456,6648915155,24681615]

print(playlist_ids)
# Out:
# [664148451, 511515115, 58519456, 6648915155, 24681615]

# %% [markdown]
# ### Task.2 :-

# %%
playlist_ids.append("54525525")
playlist_ids
# Out:
# [664148451, 511515115, 58519456, 6648915155, 24681615, '54525525']

# %%
playlist_ids.extend(["554545121548","545419851"])
playlist_ids
# Out:
# [664148451,
#  511515115,
#  58519456,
#  6648915155,
#  24681615,
#  '54525525',
#  '554545121548',
#  '545419851']

# %% [markdown]
# ### Task.3 :-

# %%
playlist_ids.pop()
# Out:
# '545419851'

# %%
playlist_ids
# Out:
# [664148451,
#  511515115,
#  58519456,
#  6648915155,
#  24681615,
#  '54525525',
#  '554545121548']

# %% [markdown]
# ### Task.4 :-

# %%
insta_filter = ("Claredon","Juno","Valencia","Lark")
print(insta_filter)
# Out:
# ('Claredon', 'Juno', 'Valencia', 'Lark')

# %%
insta_filter[0] = "Ludwig"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 insta_filter[0] = "Ludwig"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Task.5 :-

# %%
zomato_orders = ["Pizza", "Burger", "Pasta"]

"""
--->Recent Zomato orders can change (add/remove orders),
--->so a LIST is the best choice for zomato_order.    
"""

ipl_teams = ("Gujarat Titans""Mumbai Indians","Chennai Super Kings","Royal Challengers Bengaluru","Kolkata Knight Riders",
            "Delhi Capitals","Punjab Kings","Lucknow Super Giants","Sunrises Hyedrabad","Rajasthan Royals")

"""
-->IPL team names are generally fixed and should not be modified,
-->so a TUPLE is the best choice for ipl_team.
"""

print(zomato_orders)
print(ipl_teams)
# Out:
# ['Pizza', 'Burger', 'Pasta']
# ('Gujarat TitansMumbai Indians', 'Chennai Super Kings', 'Royal Challengers Bengaluru', 'Kolkata Knight Riders', 'Delhi Capitals', 'Punjab Kings', 'Lucknow Super Giants', 'Sunrises Hyedrabad', 'Rajasthan Royals')
