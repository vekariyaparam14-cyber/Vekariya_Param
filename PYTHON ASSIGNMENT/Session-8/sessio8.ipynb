# %% [markdown]
# # <---------------- Session-8 -------------------->

# %% [markdown]
# ### Task.1 :- Create a Python script that uses a for loop to print the names of 5 favorite food delivery apps (e.g., Zomato, Swiggy, etc.), one per line.

# %%
a = ["Zomato","Swiggy","Toing","McDonald's","Zepto"]

print("FOOD DELIVERY APPS:")
for i in a:
    print(i)
# Out:
# FOOD DELIVERY APPS:
# Zomato
# Swiggy
# Toing
# McDonald's
# Zepto

# %% [markdown]
# ### Task.2 :- Given a list of daily step counts for a week, use a while loop to find and print the first day when you crossed 10,000 steps.
#
# Hint: Loop through the list and stop as soon as you find a value greater than 10,000.

# %%
daily_steps = [5000,6500,7000,10000,10500,12000,17000]
days = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]

i = 0
while i < len(daily_steps):
    if daily_steps[i] > 10000:
        print("First day crossing 10,000 steps:", days[i])
        print("Steps:", daily_steps[i])
        break
    i += 1
# Out:
# First day crossing 10,000 steps: Friday
# Steps: 10500

# %% [markdown]
# ### Task.3 :- Write a Python function that takes a list of IPL team names and prints only those teams whose names are longer than 6 characters, skipping the rest using the continue statement.

# %%
ipl = ["Gujarat Titans","DC","Sun Rises Hyedrabad","Royal Challengers Banglore","Chennai Super Kings","Mumbai Indians","LSG","RR","PK","KKR"]

for i in ipl:
    if len(i) < 6:
        continue
    print(i)
# Out:
# Gujarat Titans
# Sun Rises Hyedrabad
# Royal Challengers Banglore
# Chennai Super Kings
# Mumbai Indians

# %% [markdown]
# ### Task.4 :- You have a list of song durations (in seconds) from your Spotify playlist. Use a for loop with enumerate to print each song's position (starting from 1) and its duration in the format: 'Song 1: 210 seconds'.

# %%
sec = [250,650,354,581,320,510]

for index,i in enumerate(sec, start = 1):
    print(f"Song {index} : {i}")
# Out:
# Song 1 : 250
# Song 2 : 650
# Song 3 : 354
# Song 4 : 581
# Song 5 : 320
# Song 6 : 510

# %% [markdown]
# #### Task.5 :- Build a simple shopping cart total calculator: Given a list of item prices from a Flipkart cart, use a loop to sum the prices. If an item price is 0 (out of stock), skip it. Stop adding items if the running total crosses ₹2000 using break, and print the final total.
#
# Constraint: Use both break and continue in your solution.

# %%
prices = [250,150,500,600,750,350,0,230,280,654,1000]
sum = 0
for i in prices:
    if i == 0:
        continue
    sum = sum + i
    print("Product Price - ",i)
    if sum > 2000:
        print("Your total amount is crossed 2000:",sum)
        break
# Out:
# Product Price -  250
# Product Price -  150
# Product Price -  500
# Product Price -  600
# Product Price -  750
# Your total amount is crossed 2000: 2250
