# %% [markdown]
# # <---------------- Session-14 -------------------->

# %% [markdown]
# ### Task.1 :-

# %%
f = open("playlist.txt","w")
f.write("Hanuman Chalisa\n")
f.write("Shape Of You\n")
f.write("Blinding Lights\n")
f.write("Levitating\n")
f.write("Senorita")
f.close()

# %% [markdown]
# ### Task.2 :-

# %%
f = open("playlist.txt","r+")
f.read()
# Out:
# 'Hanuman Chalisa\nShape Of You\nBlinding Lights\nLevitating\nSenorita'

# %%
with open("playlist.txt","r") as f:
    for i in f:
        print(i.upper())
# Out:
# HANUMAN CHALISA
#
# SHAPE OF YOU
#
# BLINDING LIGHTS
#
# LEVITATING
#
# SENORITA

# %% [markdown]
# ### TASK.3 :-

# %%
import csv

with open("ipl.csv","r") as a:
    read = csv.DictReader(a)
    
    for i in read:
        print(i[match_id],i[team1],i[team2],i[winner])

# %%
data = {
    ("Match 1" , "GT", "CSK", "GT"),
    ("Match 2" , "RCB", "MI", "RCB"),
    ("Match 3" , "RR", "SRH", "SRH"),
    ("Match 4" , "DC", "LSG", "DC"),
    ("Match 5" , "KKR", "PK", "PK")
}

# %%
with open("ipl.csv","w", newline="") as a:
    write = csv.writer(a)
    write.writerows(data)
    
data
# Out:
# {('Match 1', 'GT', 'CSK', 'GT'),
#  ('Match 2', 'RCB', 'MI', 'RCB'),
#  ('Match 3', 'RR', 'SRH', 'SRH'),
#  ('Match 4', 'DC', 'LSG', 'DC'),
#  ('Match 5', 'KKR', 'PK', 'PK')}

# %% [markdown]
# ### Task.4 :-

# %%
a = [
        {"Movie1" : "Dhurandhar", "year" : 2025, "rating" : 4.9},
        {"Movie" : "KGF-2", "year" : 2025, "rating" : 4.8},
        {"Movie" : "Salar", "year" : 2023, "rating" : 4.9}
    ]

# %%
import json

with open("movie.json","w") as b:
    json.dump(a,b)

# %%
with open("movie.json","r") as a:
    data1 = json.load(a)

# %%
data1
# Out:
# [{'Movie1': 'Dhurandhar', 'year': 2025, 'rating': 4.9},
#  {'Movie': 'KGF-2', 'year': 2025, 'rating': 4.8},
#  {'Movie': 'Salar', 'year': 2023, 'rating': 4.9}]

# %% [markdown]
# ### Task.5 :-

# %%
from pathlib import Path
Path('my_fav_apps.json').exists()
# Out:
# True

# %%
apps = [
        {"name": "Instagram", "category": "Social Media"},
        {"name": "Zomato", "category": "Food Delivery"},
        {"name": "Paytm", "category": "Payments"}
    ]

# %%
with open("my_fav_apps.json","w") as f:
    json.dump(apps,f)

# %%
with open("my_fav_apps.json","r") as f:
    data2 = json.load(f)

# %%
data2
# Out:
# [{'name': 'Instagram', 'category': 'Social Media'},
#  {'name': 'Zomato', 'category': 'Food Delivery'},
#  {'name': 'Paytm', 'category': 'Payments'}]
