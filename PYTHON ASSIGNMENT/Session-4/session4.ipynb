# %% [markdown]
# # <---------------- Session-4 -------------------->

# %% [markdown]
# ### Task.1 :-

# %%
String = "Flipkart-Sale2024"
a = String.lower()
print(a)
b =String.replace("-"," ")
b
# Out:
# flipkart-sale2024
# 'Flipkart Sale2024'

# %% [markdown]
# ### Task.2 :-

# %%
Product_name = " OnePlus Nord-CE 3 "
a = Product_name.strip()
print(a)
b= Product_name.upper()
print(b)
c = Product_name.replace("-",":")
c
# Out:
# OnePlus Nord-CE 3
#  ONEPLUS NORD-CE 3
# ' OnePlus Nord:CE 3 '

# %% [markdown]
# ### Task.3 :-

# %%
Product_code = "ZOMATO-FOOD-2024"

a = Product_code.replace("-"," ")
b = a.split()
b
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %% [markdown]
# ### Task.4 :-

# %%
a = "Spotify_Premium_Offer"

b = a.find("Premium")
c = a.find("Offer")
d = a[b:c-1]
d
# Out:
# 'Premium'

# %% [markdown]
# ### Task.5:-

# %%
product = "Myntra Shirt"
price =  799.50

print(f"Deal : {product} is availabe at {price} only!")
# Out:
# Deal : Myntra Shirt is availabe at 799.5 only!
