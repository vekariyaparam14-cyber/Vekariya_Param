# %% [markdown]
# # <---------------- Session-2 -------------------->

# %% [markdown]
# ### Task.1 :- Create three variables in Python named item_price, delivery_fee, and coupon_discount, and assign them values representing a Swiggy order (e.g., 250, 30, 20). Print each variable.

# %%
item_price = 250
delivery_fees = 30
coupen_discount = 20

print("<------- Bill ------->")
print("Your Item Price :  ",item_price)
print("Delivery_fees   :  ",delivery_fees)
print("Your Discount   :  ",coupen_discount)

total = item_price + delivery_fees - coupen_discount

print("Total Amount    :  ",total)
print("Including all tax.")
# Out:
# <------- Bill ------->
# Your Item Price :   250
# Delivery_fees   :   30
# Your Discount   :   20
# Total Amount    :   260
# Including all tax.

# %% [markdown]
# ### Task.2 :- Write a Python script that uses indentation correctly to check if a Flipkart product's price is above 1000; if yes, print 'Eligible for free delivery', else print 'Delivery charges apply'.
#
# #### Hint: Use an if-else block and make sure your indentation is consistent.

# %%
product_amount = int(input("Enter Your amount:"))
print("Your Product Price is: ",product_amount)

if product_amount > 1000:
    print("Eligible for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Your Product Price is:  108
# Delivery charges apply

# %% [markdown]
# ### Task.3 :- Add both single-line and multi-line comments in your script explaining what each section does, using # for single-line and triple quotes for multi-line comments.

# %%
"""
From Above Program:
==>It will shows the eligibility of getting Free Delivery
-->If product price is above 1000/-, then customer will get free delivery fees
   else it should be charge the delivery fees
"""
product_amount = int(input("Enter Your amount:"))       # User can input their product price
print("Your Product Price is: ",product_amount)         # It will shows the price of user's product

if product_amount > 1000:                               # check the price of user's product is above 1000 or not
    print("Eligible for free delivery")                 # If yes then it will Eligible for free delivery.
else:                                                   # If not 
    print("Delivery charges apply")                     # It will not Eligible for free delivery.
# Out:
# Your Product Price is:  1080
# Eligible for free delivery

# %% [markdown]
# ### Task.4 :- Create variables for an IPL match: team_name, runs_scored, and overs_played. Assign appropriate values and print them using the correct naming conventions for Python variables.
#
# #### Constraint: Use snake_case for all variable names.

# %%
team_name = "Gujarat Titans"
run_scored = 235
wicket = 5
overs_played = 20

print("Team Name     : ",team_name)
print(f"Run Scored    : {run_scored}/{wicket}")
print("overs_played  : ",overs_played)
# Out:
# Team Name     :  Gujarat Titans
# Run Scored    : 235/5
# overs_played  :  20
