# %% [markdown]
# # <-------------- Session-1 --------------->

# %% [markdown]
# ### Task.1 :-

# %%
# Already Done on Classroom

# %% [markdown]
# ### Task.2 :-

# %%
Name = "Param"
Fav_app = "Instagram"

print("My name is:",Name)
print("My favourite app is:",Fav_app)
# Out:
# My name is: Param
# My favourite app is: Instagram

# %% [markdown]
# ### Task.3 :-

# %%
print("Welcome to Data Science with Python!.")
# Out:
# Welcome to Data Science with Python!.

# %% [markdown]
# ### Task.4 :-

# %%
# hello_app.py
