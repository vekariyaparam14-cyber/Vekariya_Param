# %% [markdown]
# # <---------------- Session-3 -------------------->

# %% [markdown]
# ### Task.1 :-

# %%
Name = "Vekariya Param"
Age = 18
Height = 165.60
Spotify_account = True

print("My name is ",Name,".",type(Name))
print(f"I am {Age} year old.",type(Age))
print(f"I am {Height}cm tall.",type(Height))
print("I have Spotify account.",type(Spotify_account))
# Out:
# My name is  Vekariya Param . <class 'str'>
# I am 18 year old. <class 'int'>
# I am 165.6cm tall. <class 'float'>
# I have Spotify account. <class 'bool'>

# %% [markdown]
# ### Task.2 :-

# %%
item_price = 199.99
delivery_fees = 49
coupen_discount = 35.65

print("<------- Bill ------->")
print("Your Item Price :  ",item_price)
print("Delivery_fees   :  ",delivery_fees)
print("Your Discount   :  ",coupen_discount)

total = item_price + delivery_fees - coupen_discount

print("Total Amount    :  ",total)
print("Including all tax.")
# Out:
# <------- Bill ------->
# Your Item Price :   199.99
# Delivery_fees   :   49
# Your Discount   :   35.65
# Total Amount    :   213.34
# Including all tax.

# %% [markdown]
# ### Task.3 :-

# %%
a = int(input("Enter Your Score:"))
print("Your Score:",a)

if a >= 50:
    print("You scored HALF-CENTURY!")
else:
    print("Keep Going!")
# Out:
# Your Score: 75
# You scored HALF-CENTURY!

# %% [markdown]
# ### Task.4 :-

# %%
is_premium = "True"

is_premium = (is_premium == "True")

print(is_premium, type(is_premium))
# Out:
# True <class 'bool'>
