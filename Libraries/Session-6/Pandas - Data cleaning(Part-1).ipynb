# %% [markdown]
# # <--------- Session-5 --------->

# %%
import pandas as pd

# %% [markdown]
# Task.1 :- Download a sample CSV file of IPL player stats (include columns like player name, runs, matches, and some missing values). Load it into a pandas DataFrame and use isnull() and notnull() to print how many missing values are present in each column.

# %%
a = pd.read_csv(r"C:\PYTHON\Assignments-\Libraries\Session-6\IPL dataset final.csv")
a
# Out:
#                  Player COUNTRY TEAM  AGE  CAPTAINCY EXP  Paying_Role  Mat  \
# 0       Ruturaj Gaikwad     IND  CSK   26              0      Batting   36
# 1           Shivam Dube     IND  CSK   29              0  All rounder   35
# 2         Ambati Rayudu     IND  CSK   37              0      Batting  188
# 3          Devon Conway      NZ  CSK   31              0      Batting    7
# 4             Moeen Ali     ENG  CSK   35              0  All rounder   44
# ..                  ...     ...  ...  ...            ...          ...  ...
# 177         Abdul Samad     IND  SRH   21              0  All rounder   25
# 178         Umran Malik     IND  SRH   23              0      Bowling   17
# 179    Fazalhaq Farooqi     AFG  SRH   22              0      Bowling    3
# 180  Jagadeesha Suchith     IND  SRH   29              0  All rounder   22
# 181         T Natarajan     IND  SRH   31              0      Bowling   35
#
# ...

# %%
a.isnull().sum()
# Out:
# Player             0
# COUNTRY            0
# TEAM               0
# AGE                0
# CAPTAINCY EXP      0
# Paying_Role        0
# Mat                0
# Inns              57
# Runs              57
# BF                57
# HS                57
# Avg               56
# SR                57
# NO                57
# 4s                57
# 6s                57
# 0s                58
# 50s               58
# 100s              58
# TMat              64
# TInns            102
# TRuns            102
# TBF              102
# THS              102
# TAvg             102
# TSR              102
# TNO              102
# T4s              102
# T6s              102
# T0s              102
# T50s             102
# T100s            102
# B_Inns            67
# B_Balls           68
# B_Runs            67
# B_Maidens         68
# B_Wkts            67
# B_Avg             67
# B_Econ            67
# B_SR              67
# B_4w              67
# B_5w              67
# B_TInns          104
# ...

# %%
a.notnull().sum()
# Out:
# Player           182
# COUNTRY          182
# TEAM             182
# AGE              182
# CAPTAINCY EXP    182
# Paying_Role      182
# Mat              182
# Inns             125
# Runs             125
# BF               125
# HS               125
# Avg              126
# SR               125
# NO               125
# 4s               125
# 6s               125
# 0s               124
# 50s              124
# 100s             124
# TMat             118
# TInns             80
# TRuns             80
# TBF               80
# THS               80
# TAvg              80
# TSR               80
# TNO               80
# T4s               80
# T6s               80
# T0s               80
# T50s              80
# T100s             80
# B_Inns           115
# B_Balls          114
# B_Runs           115
# B_Maidens        114
# B_Wkts           115
# B_Avg            115
# B_Econ           115
# B_SR             115
# B_4w             115
# B_5w             115
# B_TInns           78
# ...

# %% [markdown]
# Task. 2 :- Using the loaded IPL player stats DataFrame, apply dropna(axis=0, how='any') to remove all rows with any missing data and display the shape of the DataFrame before and after dropping.

# %%
a = pd.read_csv(r"C:\PYTHON\Assignments-\Libraries\Session-6\IPL dataset final.csv")
a
# Out:
#                  Player COUNTRY TEAM  AGE  CAPTAINCY EXP  Paying_Role  Mat  \
# 0       Ruturaj Gaikwad     IND  CSK   26              0      Batting   36
# 1           Shivam Dube     IND  CSK   29              0  All rounder   35
# 2         Ambati Rayudu     IND  CSK   37              0      Batting  188
# 3          Devon Conway      NZ  CSK   31              0      Batting    7
# 4             Moeen Ali     ENG  CSK   35              0  All rounder   44
# ..                  ...     ...  ...  ...            ...          ...  ...
# 177         Abdul Samad     IND  SRH   21              0  All rounder   25
# 178         Umran Malik     IND  SRH   23              0      Bowling   17
# 179    Fazalhaq Farooqi     AFG  SRH   22              0      Bowling    3
# 180  Jagadeesha Suchith     IND  SRH   29              0  All rounder   22
# 181         T Natarajan     IND  SRH   31              0      Bowling   35
#
# ...

# %%
a.shape
# Out:
# (182, 53)

# %%
b = a.dropna(axis = 0, how = "any")
b
# Out:
#                   Player COUNTRY TEAM  AGE  CAPTAINCY EXP  Paying_Role  Mat  \
# 1            Shivam Dube     IND  CSK   29              0  All rounder   35
# 4              Moeen Ali     ENG  CSK   35              0  All rounder   44
# 6        Ravindra Jadeja     IND  CSK   34              1  All rounder  210
# 9           Dwayne Bravo      WI  CSK   39              0  All rounder  161
# 10      Mitchell Santner      NZ  CSK   31              0  All rounder   12
# 11          Chris Jordan     ENG  CSK   34              0  All rounder   28
# 21        Mitchell Marsh     AUS   DC   31              0  All rounder   29
# 23            Axar Patel     IND   DC   29              0  All rounder  122
# 25        Shardul Thakur     IND   DC   31              0  All rounder   75
# 35         Hardik Pandya     IND   GT   29              1  All rounder  107
# 43           Rashid Khan     AFG   GT   24              0  All rounder   92
# ...

# %%
a.shape
# Out:
# (39, 53)

# %% [markdown]
# Task. 3 :- For the 'runs' column in your IPL player stats DataFrame, use fillna() to replace missing values with the mean of the column. Print the updated column to verify the changes.

# %%
a["Runs"]
# Out:
# 0      1207.0
# 1       688.0
# 2      4190.0
# 3       252.0
# 4       910.0
#         ...
# 177     226.0
# 178       NaN
# 179       NaN
# 180      70.0
# 181       NaN
# Name: Runs, Length: 182, dtype: float64

# %%
a["Runs"].mean()
# Out:
# np.float64(1058.512)

# %%
a["Runs"].fillna(a["Runs"].mean())
# Out:
# 0      1207.000
# 1       688.000
# 2      4190.000
# 3       252.000
# 4       910.000
#          ...
# 177     226.000
# 178    1058.512
# 179    1058.512
# 180      70.000
# 181    1058.512
# Name: Runs, Length: 182, dtype: float64

# %% [markdown]
# Task. 4 :- Simulate a Zomato-style restaurant ratings dataset with some missing ratings. Use forward fill (method='ffill') to fill missing values in the ratings column, then use backward fill (method='bfill') for any remaining missing values. Show the before and after results.

# %%
z = pd.read_csv(r"C:\PYTHON\Assignments-\Libraries\Session-6\zomato_dataset.csv")
z
# Out:
#               Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
# ...

# %% [markdown]
# due to high data, I have taken only some random data

# %%
c = z["Delivery Rating"].sample(40).head(10)
c
# Out:
# 101997    3.7
# 11083     3.9
# 93408     3.9
# 65905     3.8
# 113913    3.7
# 64888     NaN
# 20079     4.0
# 33045     4.2
# 55366     NaN
# 65553     3.7
# Name: Delivery Rating, dtype: float64

# %%
c.ffill()
# Out:
# 101997    3.7
# 11083     3.9
# 93408     3.9
# 65905     3.8
# 113913    3.7
# 64888     3.7
# 20079     4.0
# 33045     4.2
# 55366     4.2
# 65553     3.7
# Name: Delivery Rating, dtype: float64

# %%
c.bfill()
# Out:
# 101997    3.7
# 11083     3.9
# 93408     3.9
# 65905     3.8
# 113913    3.7
# 64888     4.0
# 20079     4.0
# 33045     4.2
# 55366     3.7
# 65553     3.7
# Name: Delivery Rating, dtype: float64

# %% [markdown]
# Task. 5 :- Pick any one column with missing values from your dataset and explain which missingness mechanism (MCAR, MAR, or MNAR) is most likely and why, using 2-3 sentences.<br><br><em><strong>Hint:</strong> Think about whether the missing data is random or related to other factors in the dataset.</em>

# %%
# doubt
