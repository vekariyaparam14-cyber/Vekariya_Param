# %% [markdown]
# # <--------- Session-4 --------->

# %%
import pandas as pd

# %% [markdown]
# Task.1 :- Download a sample CSV file of IPL cricket match scores from Kaggle or any public dataset, and use pd.read_csv() to load it into a DataFrame. Print the first 5 rows to verify the data.

# %%
a = pd.read_csv(r"C:\PYTHON\Assignments-\Libraries\Session-4\deliveries.csv")

# %%
a.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %% [markdown]
# Task.2 :-Find a small JSON dataset of trending songs (for example, from Spotify's API samples or any open JSON file), and use pd.read_json() to import it into a DataFrame. Display the DataFrame's column names and data types using df.info().

# %%
b = pd.read_json(r"C:\PYTHON\Assignments-\Libraries\Session-4\data.json")

# %%
b.dtypes
# Out:
# title        str
# artist       str
# artwork      str
# url          str
# id         int64
# dtype: object

# %% [markdown]
# Task.3 :- You have a TSV (tab-separated values) file containing Zomato restaurant data. Use pd.read_csv() with the correct separator to load the data, and then use df.describe(include='all') to generate summary statistics.<br><br><em><strong>Hint:</strong> The separator for TSV files is '\t'.</em>

# %%
df = pd.read_csv(r"C:\PYTHON\Assignments-\Libraries\Session-4\output-onlinetsvtools.tsv", sep = "\t")

# %%
df.describe(include="all")
# Out:
#                     links\tnames\tratings\tcuisine\tprice  for      one  \
# count                                                 657  653      625
# unique                                                657  453      316
# top     https://www.zomato.com/hyderabad/sahara-bakers...    -  Indian,
# freq                                                    1   22       34
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# count         551        454        348        253        180        121
# unique        223        190        129         97         76         62
# top       Indian,    Indian,    Indian,      Food,      Food,  Desserts,
# freq           54         40         29         21         17         10
#
#        Unnamed: 9 Unnamed: 10 Unnamed: 11     Unnamed: 12 Unnamed: 13  \
# count          81          52          27              11           6
# unique         48          32          23              11           6
# ...

# %% [markdown]
# Task.4 :- Download a large Excel file (at least 10,000 rows) of Flipkart product listings. Use pd.read_excel() with the chunksize parameter to read the file in chunks of 2000 rows, and print the number of rows in each chunk as you iterate.

# %%
d = pd.read_excel(r"C:\PYTHON\Assignments-\Libraries\Session-4\flipkart.xlsx")

# %%
d
# Out:
#        product_id        product_name        category     brand        seller  \
# 0      FKP0000001    Adidas Ultra 664            Toys    Adidas     MegaStore
# 1      FKP0000002       LG Series 124         Fashion        LG     ValueKart
# 2      FKP0000003      Redmi Model 35          Beauty     Redmi    SmartDeals
# 3      FKP0000004    Sony Edition 769            Toys      Sony  UrbanRetails
# 4      FKP0000005      Boat Prime 291  Home & Kitchen      Boat     RetailHub
# ...           ...                 ...             ...       ...           ...
# 79995  FKP0079996  Prestige Ultra 500          Sports  Prestige     MegaStore
# 79996  FKP0079997      Sony Prime 225         Mobiles      Sony     QuickShop
# 79997  FKP0079998       LG Series 545          Beauty        LG  UrbanRetails
# 79998  FKP0079999    Reebok Model 744            Toys    Reebok     MegaStore
# 79999  FKP0080000      Puma Ultra 650  Home & Kitchen      Puma     ValueKart
#
# ...

# %%
d[0:2000]
# Out:
#       product_id       product_name        category    brand        seller  \
# 0     FKP0000001   Adidas Ultra 664            Toys   Adidas     MegaStore
# 1     FKP0000002      LG Series 124         Fashion       LG     ValueKart
# 2     FKP0000003     Redmi Model 35          Beauty    Redmi    SmartDeals
# 3     FKP0000004   Sony Edition 769            Toys     Sony  UrbanRetails
# 4     FKP0000005     Boat Prime 291  Home & Kitchen     Boat     RetailHub
# ...          ...                ...             ...      ...           ...
# 1995  FKP0001996  Reebok Series 376         Mobiles   Reebok     MegaStore
# 1996  FKP0001997     LG Edition 818     Electronics       LG     QuickShop
# 1997  FKP0001998       LG Prime 817         Mobiles       LG     ValueKart
# 1998  FKP0001999       LG Model 253            Toys       LG     SuperMart
# 1999  FKP0002000  Philips Model 612         Mobiles  Philips       BestBuy
#
# ...

# %% [markdown]
# Task.5 :- Use ChatGPT or Copilot to generate a Python code snippet that reads a semicolon-separated CSV of Paytm transactions, detects missing values, and prints out which columns have nulls. Test the code with a small sample file and fix any errors you encounter.

# %%
df = pd.read_csv(r"C:\PYTHON\Assignments-\Libraries\Session-4\business.csv")

# %%
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 9550     BDCQ.SF8RSCA  2025.03     699.681        NaN      F  Dollars
# 9551     BDCQ.SF8RSCA  2025.06     587.843        NaN      F  Dollars
# 9552     BDCQ.SF8RSCA  2025.09     658.866        NaN      F  Dollars
# 9553     BDCQ.SF8RSCA  2025.12     734.757        NaN      F  Dollars
# 9554     BDCQ.SF8RSCA  2026.03     884.011        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
print(df.isnull().sum())
null_columns = df.columns[df.isnull().any()].tolist()

if null_columns:
    print("\nColumns containing null values:")
    for col in null_columns:
        print(f"- {col}")
else:
    print("\nNo null values found.")
# Out:
# Series_reference       0
# Period                 0
# Data_value            45
# Suppressed          9540
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# Series_title_3         0
# Series_title_4         0
# Series_title_5      9555
# dtype: int64
#
# Columns containing null values:
# - Data_value
# - Suppressed
# - Series_title_5
